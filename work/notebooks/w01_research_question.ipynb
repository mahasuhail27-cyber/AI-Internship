# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahasuhail27-cyber/AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose the Content Performance and Trend Analysis lane. My goal is to identify content that is losing performance so that editors can update it before traffic declines further.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/mahasuhail27-cyber/AI-Internship.git
# Out:
# Cloning into 'AI-Internship'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 124 (delta 39), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.85 MiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
print(df["trend_direction"].value_counts())
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
# Decision:
# Which content pages should be updated first?
#
# Action:
# A content manager can prioritize updating pages that show signs of declining performance.
#
# Cost of a wrong recommendation:
# If a healthy page is marked as declining, time and resources may be wasted. If a declining page is missed, website traffic and user engagement may continue to decrease.
#
# Why data or ML helps:
# Content performance depends on several factors such as CTR, impressions, engagement rate, average position, and traffic trends. Machine learning can identify patterns across these features more effectively than simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The dataset contains multiple content performance metrics including CTR, engagement rate, average search position, impressions, and traffic trends. These metrics provide enough information to analyze content performance and support data-driven decisions.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
# This project identifies patterns in historical data. The analysis does not prove that any single factor causes content performance to improve or decline. Predictions should support human decision-making rather than replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
